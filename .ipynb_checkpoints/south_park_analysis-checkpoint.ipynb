# %%
from __future__ import division

import re
import sys

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import RidgeClassifierCV, Ridge, LogisticRegression
from sklearn.cross_validation import cross_val_score

# %matplotlib inline

from pylab import rcParams

rcParams['figure.figsize'] = 15, 10
plt.style.use('fivethirtyeight')

reload(sys)
sys.setdefaultencoding("utf-8")

# %%
#data source: https://github.com/BobAdamsEE/SouthParkData
#includes all south park dialogue from the first epsiode to
sp = pd.read_csv('all-seasons.csv',encoding='latin1')

#scraped from http://www.imdb.com/list/ls008123404/?start=1&view=compact&sort=user_rating:desc&defaults=1&scb=0.4095939879637156
imdb = pd.read_csv('imdb.csv',dtype={'raw_episode':unicode})

# %%
#some string cleaning
sp.character = sp.character.str.replace('Mr ', 'Mr. ')
sp.character = sp.character.str.replace(':|,|;','')

# %%
sp.tail()
# Out:
#       season episode character                              line
# 70890      9      14      Stan      I think you're pushing it.\n
# 70891      9      14     Randy               How about twenty?\n
# 70892      9      14      Stan          That's not disciprine.\n
# 70893      9      14     Randy  Right right. Does vodka count?\n
# 70894      9      14      Stan                            Dad!\n

# %%
imdb.head()
# Out:
#   raw_episode                                      episode_title  rating  \
# 0         5.4                            Scott Tenorman Must Die     9.6
# 1        10.8                            Make Love, Not Warcraft     9.6
# 2        6.13  The Return of the Fellowship of the Ring to th...     9.3
# 3        18.7                                 Grounded Vindaloop     9.2
# 4         8.5                                           AWESOM-O     9.2
#
#    number_of_votes
# 0             4324
# 1             4138
# 2             2310
# 3             2004
# 4             2041

# %%
imdb['season']= imdb.raw_episode.str.split('.').map(lambda x: x[0]).astype(int)
imdb['episode']= imdb.raw_episode.str.split('.').map(lambda x: x[1]).astype(int)

# %%
#sort by season and episode 
imdb.sort_values(['season','episode'],inplace=True)
imdb['episode_number']=range(1,len(imdb)+1)

# %%
#remove rows that are repetition of the column headers
sp = sp[sp.season!='Season']

#convert season and episode to int dtype
sp.season = sp.season.astype(int)
sp.episode = sp.episode.astype(int)

sp.sort_values(['season','episode'],inplace=True)

# %%
#determine the epsiode number for each episode 
episode_key = sp.groupby(['season','episode'],as_index=False)['line'].count()
episode_key['episode_number']=range(1,len(episode_key.line)+1)
sp = sp.merge(episode_key[['season','episode','episode_number']],on=['season','episode'],how='left')

# %%
#Join the IMDB ratings data with the text data.
#Note that this drops season 19 and the last episode of season 18 from IMDB as 
#neither are in the
sp = sp.merge(imdb[['episode_number','episode_title','rating','number_of_votes']],on='episode_number',how='left')

# %%
def make_text_features(df,col,inplace=False):
    '''
    Calculates summary statistics on a text column and appends features to original dataframe.
    '''
    
    if inplace:
        frame=df
    else:
        frame=df.copy()
    frame[col] = frame[col].fillna(' ')
    frame['number_of_words'] = frame[col].map(lambda x: len(x.split()))
    frame['number_of_characters'] = frame[col].map(lambda x: len(x))
    
    #First replace removes punctuation and numbers. Second replace change new line characters to spaces.
    frame['clean_text'] = frame[col].str.replace('\!|\?|\.|\,|\'|\"',"").str.replace('\n+\r*',' ').fillna(' ')
    
    #for lambda function, the numerator is length of the words after removing word delimiters
    #for the denominator, this is the number of words. To avoid dividing by zero errors there is a max(1,_) option 
    frame['mean_word_length'] = frame.clean_text.map(lambda x: len(''.join(x.split()))/ max(1,len(x.split())))
    
    #finds the length of the longest word in the line
    frame['length_longest_word'] = frame.clean_text.map(lambda x: len(max(x.split(),key=len)))    
    
    #counts number of words that refer to the
    frame['count_self_references'] = frame[li].str.findall('(i |me|my|mine|im)', re.IGNORECASE).map(len)
    return frame

sp = make_text_features(sp,'line')

# %%
sp.clean_text.str.findall('(i |me|my|mine|im)', re.IGNORECASE)#.map(len)
# Out:
# 0                          []
# 1                          []
# 2                          []
# 3                        [Im]
# 4                          []
# 5                          []
# 6                          []
# 7                        [me]
# 8                        [I ]
# 9        [Im, im, Im, I , im]
# 10                         []
# 11                         []
# 12                         []
# 13                         []
# 14                         []
# 15                         []
# 16                         []
# 17                       [im]
# 18                         []
# 19                         []
# 20                         []
# 21                         []
# 22                         []
# 23                         []
# 24                         []
# 25                         []
# 26                       [I ]
# 27                         []
# 28                         []
# 29                         []
#                  ...
# ...

# %%
def central_characters(sp,n=20):
    '''
    Returns a list of the top n characters who have the most lines.
    '''
    characters = sp.groupby('character',as_index=False).count().sort_values('line',ascending=False).head(n)
    characters = characters.character.tolist()
    return characters

##### copy of south park dataframe where characters are put into buckets ###########
sp_main_characters = sp.copy()

#bucket the 4 boys together
sp_main_characters.character = sp_main_characters.character.str.replace('Stan|Cartman|Kenny|Kyle','The Boys')

n_supporting_characters = 23
central_characters_lst = central_characters(sp_main_characters,n_supporting_characters)

sp_main_characters.ix[sp_main_characters.character.isin(central_characters_lst[3:]),
                     ['character']] = "Top %s Supporting Characters" % str(n_supporting_characters-3)

#bucket all remaining characters together as "Other Character"
sp_main_characters.ix[~((sp_main_characters.character.isin(central_characters_lst[:3]))|(sp_main_characters.character=="Top %s Supporting Characters" % str(n_supporting_characters-3))),
                     ['character']] = "Other Characters"

# %%
#calculate the % of lines per epsiode for each character group
lines_per_epsiode = sp_main_characters.groupby(['episode_number','season','character']).count()[['line']].unstack(level=2)
lines_per_epsiode.columns = lines_per_epsiode.columns.droplevel()
lines_per_epsiode = lines_per_epsiode.div(lines_per_epsiode.sum(axis=1), axis=0).round(4)*100

# %%
lines_per_epsiode.reset_index().drop('episode_number',axis=1).groupby(['season']).mean().fillna(0).rolling(1).mean().plot()

# %%
character_stats = sp.groupby('character').sum()[['number_of_words','count_self_references']]
character_stats['percent_of_words_that_refer_to_self'] = character_stats.count_self_references / character_stats.number_of_words
character_stats['percent_of_lines'] = sp.groupby('character').count()[['line']] / len(sp)
character_stats['percent_of_words'] = sp.groupby('character').sum()[['number_of_words']] / sp.number_of_words.sum()
character_stats['final_episode_lines'] = last_lines.groupby(['character']).count()[['line']]

character_stats['mean_words_per_line'] = sp.groupby('character')[['number_of_words']].mean()
character_stats['mean_word_length'] = sp.groupby('character')[['number_of_words']].mean()
n_word_monologue = 30
sp['is_monologue']=  sp.number_of_words> n_word_monologue
#sp.groupby('character')['is_monologue'].sum().order()

# %%
character_stats.sum()
# Out:
# number_of_words                        813331.000000
# count_self_references                   60131.000000
# percent_of_words_that_refer_to_self       274.735361
# percent_of_lines                            1.000000
# percent_of_words                            1.000000
# final_episode_lines                       256.000000
# mean_words_per_line                     43706.751323
# mean_word_length                        43706.751323
# dtype: float64

# %%
central_characters_lst = central_characters(sp,20)
character_stats[character_stats.index.isin(central_characters_lst)].sort_values('percent_of_words_that_refer_to_self')
# Out:
#               number_of_words  count_self_references  \
# character
# Announcer                7446                    319
# Sheila                   5667                    321
# Stephen                  4706                    288
# Jimbo                    6934                    441
# Mr. Garrison            15062                    985
# Mr. Mackey              10655                    700
# Clyde                    2516                    175
# Sharon                   8582                    603
# Wendy                    6064                    427
# Gerald                   6813                    483
# Kyle                    63665                   4581
# Stan                    68881                   4972
# Chef                    11173                    808
# Craig                    3033                    226
# Randy                   31034                   2318
# Cartman                130045                  10776
# ...

# %%
#min_df is set to 75 in order to drop words that were frequently said, but only in an epsiode or two i.e. to prevent overfitting 
#lower the min_df and you might see funny reminders of memorable episodes for you favorite character
vec = TfidfVectorizer(ngram_range=[1,3],min_df=75,stop_words='english',encoding='latin1')
X_words = vec.fit_transform(sp.line)

# %%
#this list include main character and ones that had funny words
characters_to_predict = ['Randy','Cartman','Chef','Butters','Kanye','Coon','Kyle','Mr. Garrison','Stan','Satan','Jimbo','Kenny','Jesus','Towelie']

def generate_character_words(sp,characters_to_predict,X_words,include_coef=False):
    '''
    Generates a list of words predictive that a charater is speaking. 
    '''
    character_words= pd.DataFrame()
    for character in characters_to_predict:
        y = sp.character==character
        #this is optimized to be funny, not to generalize well (hence no cross validation). Simply, other regularizations weren't as funny 
        #and L1 was too sparse for minor characters
        model = LogisticRegression(penalty='l2')
        model_words = model.fit(X_words,y)
        
        #build a vocabularly of features and sort by coeffiencient size
        vocab = pd.DataFrame( zip(model_words.coef_[0],vec.get_feature_names()))
        vocab.columns=['coef_%s' %character,character]
        vocab = vocab.sort_values('coef_%s' %character,ascending=False).reset_index(drop=True)
        
        #include the character and their words in all cases. 
        #add the regression coeficients for each character if include_coef is True
        output_cols = [character]
        if include_coef:
            output_cols.append('coef_%s' %character)
        character_words = pd.concat([character_words,vocab[output_cols]],axis=1)
    return character_words

# %%
#examine characters' predictive words and their coefficients to check for signs of multicolinearity. Here, that would be correlated terms 
#that had opposite signs for the coefficent. Also notice that the words most unpredictive are not that different for each charatcer. 
#Stan says 'Dude' a lot and other don't. The negative words that are names do have a lot of info on which characters never interact,
#but it's not funny enough to put in the blog post.
generate_character_words(sp,characters_to_predict,X_words=X_words,include_coef=False)

# %%
#output characters' predictive words without coefficients to excel for formatting
character_words = generate_character_words(sp,characters_to_predict,X_words,include_coef=False)
character_words.head(20).to_excel('south park character words.xlsx')

# %%
#cross_val_score(model_words,X_words,y)

# %%
#count of lines per episode
lines_by_episode  = sp.groupby(['episode_number','season','episode'],as_index=False).count()[['episode_number','line']]

#unique number of charatcers per epsiode
characters_by_episode = sp.groupby(['episode_number','season','episode'],as_index=False).agg(lambda x: x.nunique())[['episode_number','character']]

#average words per line for each each episode
mean_words_per_line_by_episode = sp.groupby('episode_number',as_index=False).mean()[['episode_number','number_of_words']]

# %%
min_episode_number = sp.episode_number.min()
max_episode_number = sp.episode_number.max()

# %%
sns.lmplot(x="episode_number", y="line", data=lines_by_episode)
plt.xlabel("Episode Number")
plt.xlim(min_episode_number,max_epsiode_number)
plt.ylabel("Number of Lines")
plt.title("Lines Per Episode Over Time")
plt.tight_layout()
#plt.savefig("")

# %%
sns.lmplot(x="episode_number", y="number_of_words", data=mean_words_per_line_by_episode)
plt.xlabel("Episode Number")
plt.xlim(min_episode_number,max_epsiode_number)
plt.ylabel("Mean Word Count per Line")
plt.title("Mean Words Per Line Over Time")

# %%
sns.lmplot(x="episode_number", y="character", data=characters_by_episode)

# %%
characters = sp.groupby('character')[['line']].agg(lambda x: " ".join(x.tolist()))

# %%
characters
# Out:
#                                                                line
# character
# A Banana          Wow, Gangnamstein. I wish I'd have thought of ...
# A Bishop                                        Uh, yes they are.\n
# A Boy             It's really weird what he said. I don't know, ...
# A British Person  Aaah.  Dickens. The imagery of cobblestone str...
# A British person  And they all lived happily ever after. Except ...
# A Catfish         You chose your path wisely, Lemmiwinks. I am t...
# A Congressman     Excuse me, but does this Declaration actually ...
# A Council Member                               Hahahahaha, oh my.\n
# A Cowboy          Come on, Helen. Let's just go back to hell. I'...
# A Dentist                                         Dentist office.\n
# A Diner                           Oh my God, it's the President! \n
# A Doctor          Well hello there, little girl. My name is Dr. ...
# A Driver          And what are four little boys going to do to s...
# ...

# %%
sp['season_text'] = sp.groupby('season').transform(lambda x: " ".join(x.tolist())).line

# %%
#sp[sp.character.isin(central_characters(sp,20))].groupby(['season','character']).agg(lambda x: " ".join(x.tolist()))

# %%
#assign a value of -1 to all lines from seasons 1-9 and a value of 1 to a line from seasons 10 - 18
sp['series_half'] = np.where((sp.season<= 9 ),-1,1)
sp.series_half.value_counts(normalize=True)
# Out:
# -1    0.609823
#  1    0.390177
# Name: series_half, dtype: float64

# %%
#there are not an even number of lines in each half
sp['series_half_normalized'] = sp.series_half.map(lambda x: (2*x*.390177) if x==-1 else 2*(x*.609823))

# %%
sp[sp.character.isin(central_characters(sp,25))].groupby('character').mean(
)[['series_half_normalized']].sort_values('series_half_normalized')#.plot.box(vert=False)
# Out:
#                     series_half_normalized
# character
# Chef                             -0.680027
# Mr. Garrison                     -0.558797
# Jimbo                            -0.550138
# Terrance                         -0.404467
# Sheila                           -0.373994
# Linda                            -0.308132
# Jesus                            -0.285177
# Stan                             -0.165571
# Gerald                           -0.119012
# Kyle                             -0.091409
# Kenny                            -0.087871
# Liane                            -0.078116
# Mr. Mackey                        0.017753
# Jimmy                             0.018304
# Cartman                           0.026854
# Sharon                            0.079112
# Wendy                             0.132467
# Announcer                         0.135902
# Clyde                             0.168691
# Principal Victoria                0.202345
# ...

# %%
sp[sp.character.isin(central_characters(sp,25))].groupby('character').sum(
)[['series_half_normalized']].sort_values('series_half_normalized').sum()#.plot.box(vert=False)
# Out:
# series_half_normalized   -1557.589562
# dtype: float64

# %%
#
#sp[sp.character.isin(central_characters(sp,20))].groupby('character').mean().sort_values('avg_length_word')

# %%
#no clear p
#sp[sp.character=='Kyle'].groupby(['character','season'])['is_speech'].sum().unstack(level=0).plot(kind='bar')

# %%
last_lines = sp.groupby(['episode_number','season'],as_index=False)[['character','line']].last()
last_lines.groupby(['character']).count()[['line']]

# %%
#all of the times someone says "learned something"
sp['learned_something']= sp.line.str.contains('learned something',case=False)

#all of the times someone says "killed kenny"
sp['killed_kenny']= sp.line.str.contains('killed kenny',case=False)

# %%
#the characters who say "killed kenny" the most 
sp.groupby('character').sum()['killed_kenny'].order().tail(5)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: order is deprecated, use sort_values(...)
#   if __name__ == '__main__':
# character
# Stuart      1.0
# Michael     1.0
# Cartman     3.0
# Kyle       12.0
# Stan       43.0
# Name: killed_kenny, dtype: float64

# %%
#the characters who say "learned something" the most 
sp.groupby('character').sum()['learned_something'].order().tail(5)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: order is deprecated, use sort_values(...)
#   from ipykernel import kernelapp as app
# character
# Wendy       1.0
# Dio         1.0
# Cartman     4.0
# Stan       11.0
# Kyle       12.0
# Name: learned_something, dtype: float64

# %%
sp.groupby(['season'])['killed_kenny'].sum().plot(kind='bar')
plt.title("They Stopped Killing Kenny")
plt.ylabel("Count of Times Someone says Killed Kenny")
plt.xlabel("Season")
plt.tight_layout()

# %%
sp.groupby(['season'])['learned_something'].sum().plot(kind='bar')
plt.title("They Stopped Learning Lessons")
plt.ylabel("Count of Times Someone Says Learned Something")
plt.xlabel("Season")
plt.tight_layout()

# %%
sp[sp.character.str.contains('^randy$',case=False)].groupby(['character','season']).count()['line'].unstack(level=0).plot(kind='bar')

# %%
sp[sp.character.str.contains('^chef$',case=False)].groupby(['character','season']).count()['line'].unstack(level=0).plot(kind='bar')

# %%
sp[sp.character.str.contains('^butters$|^stephen$',case=False)].groupby(['character','season']).count()['line'].unstack(level=0).plot(kind='bar')

# %%
sp[sp.character.str.contains('(^mr(\.)? garrison)$|(mrs(\.)? garrison$)',case=False)].groupby(['character','season']).sum()['number_of_words'].unstack(level=0).plot(kind='bar')
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   app.launch_new_instance()

# %%
sp['obama']= sp.line.str.contains('obama',case=False)
sp['bush']= sp.line.str.contains('(george|president|george w)(.)? bush',case=False)
sp['clinton']= sp.line.str.contains('(bill|president) clinton',case=False)
sp['president']= sp.line.str.contains('president',case=False)
sp['politics']= sp.line.str.contains('clinton|george bush|obama|mccain|palin|al gore|vote|romney|kerry',case=False)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   from ipykernel import kernelapp as app
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   app.launch_new_instance()

# %%
sp.groupby('season')[['president','politics']].sum().plot()
